# %%
with open("./data/concatTrain.txt","r") as f:
 for i in f.readlines():
       if not i.strip():
           continue
       if i:
           print(i),
# Out:
# word punStatus pronunciation
#
# ' O PUNCTUATION_'
#
# ' O PUNCTUATION_'
#
# I O UNKNOWN
#
# ' O PUNCTUATION_'
#
# m O EH1,M
#
# halfway O HH,AE1,F,W,EY1
#
# up O AH1,P
#
# a O AH0
#
# mountain O M,AW1,N,T,AH0,N
#
# , O PUNCTUATION_,
#
# ' O PUNCTUATION_'
#
# ' O PUNCTUATION_'
#
# Tom O UNKNOWN
#
# alleged P AH0,L,EH1,JH,D
#
# . O PUNCTUATION_.
#
# I O UNKNOWN
#
# ' O PUNCTUATION_'
#
# d O D,IY1
#
# like O L,AY1,K
#
# to O T,UW1
#
# be O B,IY1
#
# a O AH0
#
# Chinese O UNKNOWN
#
# laborer O L,EY1,B,ER0,ER0
#
# , O PUNCTUATION_,
#
# said O S,EH1,D
#
# Tom O UNKNOWN
#
# coolly P K,UW1,L,IY0
#
# . O PUNCTUATION_.
#
# Dentists O UNKNOWN
#
# don O D,AA1,N
#
# ' O PUNCTUATION_'
#
# t O T,IY1
#
# like O L,AY1,K
#
# a O AH0
#
# hard O HH,AA1,R,D
#
# day O D,EY1
#
# at O AE1,T
#
# the O DH,AH0
#
# orifice P AO1,R,AH0,F,AH0,S
#
# . O PUNCTUATION_.
#
# Are O UNKNOWN
#
# evil O IY1,V,AH0,L
#
# wildebeests O UNKNOWN
#
# bad O B,AE1,D
#
# gnus P UNKNOWN
#
# ? O PUNCTUATION_?
#
# A O UNKNOWN
#
# ...
